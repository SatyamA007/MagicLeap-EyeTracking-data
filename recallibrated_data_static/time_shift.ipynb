# %%
import matplotlib.pyplot as plt
import pandas as pd
from util import *
import numpy as np

df = pd.read_csv('w2_0308_133329_PM.csv')

# %%
x = df.seconds.astype(float).fillna(0.0).apply(lambda x: (x - df.iloc[1500]['seconds'])*1000)[1500:2000]
y1 = df.gaze_vis_x.astype(float).fillna(0.0)[1500:2000]
y2 = df.target_vis_x.astype(float).fillna(0.0)[1500:2000]

plt.figure().set_figwidth(50)
plt.plot(x, y1)
plt.plot(x, y2, '-.')
plt.xticks(np.arange(min(x), max(x)+1, 250.0))

# Now convert and plot:
plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title('multiple plots')
plt.show()

# %%
def shifted_euc_error_h(df, shift):
    # df = vis_angles_from_file(f)
    error = 0
    count = 0
    data = df[:-shift]
    if shift==0:
        data = df

    for index, row in data.iterrows():
        if row['PathIDX']==99 or row['blinks']:
            continue
        error += abs(row['target_vis_x'] - df.iloc[index + shift]['gaze_vis_x'])
        error += abs(row['target_vis_y'] - df.iloc[index + shift]['gaze_vis_y'])
        count+=1
    return error/count


min_error = float('inf')
idx = 0

for shift in range(30):
    e_after_shift = shifted_euc_error_h(df,shift)
    # print(e_after_shift)
    if min_error > e_after_shift:
        min_error = e_after_shift
        idx = shift

shifted_df = df[:-idx]
shifted_df['gaze_vis_x'] = df['gaze_vis_x'][idx:]
shifted_df['gaze_vis_y'] = df['gaze_vis_y'][idx:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'blinks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18512\2307145693.py in <module>
#      20
#      21 for shift in range(30):
# ---> 22     e_after_shift = shifted_euc_error_h(df,shift)
#      23     # print(e_after_shift)
#      24     if min_error > e_after_shift:
#
# ~\AppData\Local\Temp\ipykernel_18512\2307145693.py in shifted_euc_error_h(df, shift)
#       8
#       9     for index, row in data.iterrows():
# ---> 10         if row['PathIDX']==99 or row['blinks']:
#      11             continue
#      12         error += abs(row['target_vis_x'] - df.iloc[index + shift]['gaze_vis_x'])
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'blinks'

# %%
x = shifted_df.seconds.astype(float).fillna(0.0).apply(lambda x: (x - shifted_df.iloc[1500]['seconds'])*1000)[1500:2000]
y1 = shifted_df.gaze_vis_x.astype(float).fillna(0.0)[1500:2000]
y2 = shifted_df.target_vis_x.astype(float).fillna(0.0)[1500:2000]

plt.figure().set_figwidth(50)
plt.plot(x, y1)
plt.plot(x, y2, '-.')
plt.xticks(np.arange(min(x), max(x)+1, 250.0))

# Now convert and plot:
plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title('multiple plots')
plt.show()
# return [idx, df[]]

# %%
latency = df.iloc[idx]['seconds']*1000
